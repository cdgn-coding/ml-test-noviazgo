# %% [markdown]
# # Baseline model

# %% [markdown]
# Esta notebook presenta como utilizar el dataset con un modelo dado

# %% [markdown]
# ## Importo el dataset

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("data/train.csv", index_col = "Unnamed: 0")
test = pd.read_csv("data/test.csv", index_col = "Unnamed: 0")

# %%
y_train, y_test = train.drop('target', axis = 1, inplace = True), test.drop('target', axis = 1, inplace = True)
X_train, X_test = train, test

# %%
X_test
# Out:
#       genero_Hombre  genero_Mujer  genero_Otro  barrio_completo_Agronomia  \
# 2526              0             1            0                          0
# 2547              0             1            0                          0
# 1359              0             1            0                          0
# 3326              1             0            0                          0
# 4272              1             0            0                          0
# ...             ...           ...          ...                        ...
# 2379              0             1            0                          0
# 5505              0             1            0                          0
# 223               0             1            0                          0
# 4155              0             1            0                          0
# 1719              0             1            0                          0
#
#       barrio_completo_Almagro  barrio_completo_Balvanera  \
# 2526                        0                          1
# 2547                        0                          0
# 1359                        0                          0
# 3326                        1                          0
# 4272                        0                          0
# ...                       ...                        ...
# 2379                        0                          0
# 5505                        0                          0
# 223                         0                          0
# 4155                        0                          0
# 1719                        0                          0
#
#       barrio_completo_Barracas  barrio_completo_Belgrano  \
# 2526                         0                         0
# 2547                         0                         0
# 1359                         0                         0
# 3326                         0                         0
# 4272                         0                         0
# ...                        ...                       ...
# 2379                         0                         0
# 5505                         1                         0
# 223                          0                         0
# 4155                         0                         0
# 1719                         0                         0
#
#       barrio_completo_Boca  barrio_completo_Boedo  ...  pregunta_10_B  \
# 2526                     0                      0  ...              0
# 2547                     0                      0  ...              0
# 1359                     0                      0  ...              0
# 3326                     0                      0  ...              1
# 4272                     0                      0  ...              1
# ...                    ...                    ...  ...            ...
# 2379                     0                      0  ...              0
# 5505                     0                      0  ...              0
# 223                      0                      0  ...              0
# 4155                     0                      0  ...              1
# 1719                     0                      0  ...              1
#
#       pregunta_10_C  pregunta_11_A  pregunta_11_B  pregunta_11_C  \
# 2526              1              0              0              1
# 2547              1              0              0              1
# 1359              1              0              1              0
# 3326              0              1              0              0
# 4272              0              0              1              0
# ...             ...            ...            ...            ...
# 2379              1              0              1              0
# 5505              0              0              0              1
# 223               1              0              0              1
# 4155              0              0              0              1
# 1719              0              1              0              0
#
#       pregunta_12_A  pregunta_12_B  pregunta_12_C  edad_scaled  \
# 2526              0              0              1     0.603011
# 2547              0              0              1     1.171439
# 1359              1              0              0     0.603011
# 3326              1              0              0     1.171439
# 4272              1              0              0     0.261955
# ...             ...            ...            ...          ...
# 2379              0              1              0     0.489326
# 5505              1              0              0     1.398810
# 223               0              0              1     0.603011
# 4155              0              0              1     1.285124
# 1719              1              0              0     2.080923
#
#       poblacion_por_barrio_scaled
# 2526                     0.841805
# 2547                     1.442089
# 1359                    -0.842106
# 3326                     0.725029
# 4272                    -0.762268
# ...                           ...
# 2379                    -0.346044
# 5505                     0.042386
# 223                     -0.930008
# 4155                     2.257408
# 1719                     0.638986
#
# [1419 rows x 89 columns]
